# %% [markdown]
# # 第一章 算法简介

# %% [markdown]
# ## 引言

# %% [markdown]
# 对于每种算法，先描述并提供示例，再使用大O表示法讨论其运行时间，最后探索它可以解决的其他问题。

# %% [markdown]
# ### 需要具备的知识

# %% [markdown]
# 看懂给定函数 $f(x) = x \times 2$，$f(5)$的值是多少就够了。答案是10！

# %% [markdown]
# ## 二分查找

# %% [markdown]
# 查找有序元素列表中某一个元素

# %% [markdown]
# ### 更佳的查找方式

# %% [markdown]
# 对于n个元素的列表，用二分查找最多需要$log_2N$

# %% [markdown]
# 函数binary_search接受一个有序数组和一个元素。如果指定的元素包含在数组中，这个函数将返回其位置。你将跟踪要在其中查找的数组部分——开始时整个数组。

# %% [markdown]
# ![%E4%BA%8C%E5%88%861.png](attachment:%E4%BA%8C%E5%88%861.png)

# %%
def binary_search(list_1, item):
    """
    二分法查找有序数组元素
    :param list_1: 
    :param item: 
    :return: 
    """
    # low和high用于跟踪要在其中查找的列表部分
    low = 0
    high = len(list_1)-1
    
    # 只要范围没有缩小到只包含一个元素
    while low <= high:
        mid = (low + high)  # 就查找中间的元素
        guess = list_1[mid]
        
        # 找到了元素
        if guess == item:
            return mid
        
        # 猜的数字打了
        elif guess > item:
            high = mid - 1
            
        # 猜的数字小了
        else:
            low = mid + 1
    
    # 若没有指定的元素    
    return None

# %% [markdown]
# 测试一下

# %%
# 给出一个有序数组
my_list = [1, 3, 5, 7, 9]

# %%
# 打印元素 3
print(binary_search(my_list, 3))

# %%
# 打印元素 -1 (不在此数组中)
print()
